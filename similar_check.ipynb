# %%
import pandas as pd

# %%
for i in range(11):
    content_id = 1260018197
    logit = pd.read_csv(f'tmp/{content_id}_video/{i}/saliency_v2.csv')['logit']
    logit.plot(figsize=(16, 6), alpha=0.7)

# %%
for i in range(11):
    content_id = 1260018197
    logit = pd.read_csv(f'tmp/{content_id}_video/{i}/saliency_v2.csv')['saliency']
    logit.plot(figsize=(16, 6), alpha=0.7)
